# %%
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image
from scipy import ndimage
import os

# %matplotlib inline

# %%
original_dir = '/home/nikos/workspace/coin-detector/data/500'
original = os.path.join(original_dir, 'orig.jpg')

img = np.copy(np.asarray(Image.open(original, 'r')))

if img.ndim == 3:
    img = np.mean(img, 2)

img[img >= 245] = np.random.randint(0, 50)

half = img.shape[1] / 2
front = img[:, 0:int(half)]
back = img[:, int(half):]

fig = plt.figure()
fig.add_subplot(1,2,1)
plt.imshow(front)
fig.add_subplot(1,2,2)
plt.imshow(back)

# %%
rotate = lambda img, rot: ndimage.interpolation.rotate(img, rot, cval=10, reshape=False)

def make_imgs(img):
    rots = range(0, 360, 10)
    for x in rots:
        img = rotate(front, x)
        for shad in [0.6, 0.8, 1]:
            path = os.path.join(original_dir, '{}-{}.png'.format(x, shad))
            plt.imsave(path, img * shad, cmap='gray', vmax=256)
            
make_imgs(front)
